# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranil199/100-DAYS-OF-PYTHON/blob/main/CB_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2+1
# Out:
# 3

# %%
2-1
# Out:
# 1

# %%
2*1
# Out:
# 2

# %%
2/1
# Out:
# 2.0
